# %% [markdown]
# ### Introduction:
# #### Business Problem :
#
# Problem Statement : To find the optimal solution to leverage the accidents occurances based on the differert attibuted data with ML system in place
# The idea of this project is to help people planning their pre-requistes for the travel with regards of the loaction & Climatic conditions
# Since there are lots of accidents occuring we will try to detect locations that are having high impact with climatic conditions as well
# We will use our data science powers to generate a few most promissing results based on this criteria.
# Advantages of this will result in so that best possible solution can be chosen by stakeholders.
#
# #### Data Description :
#
# Based on definition of our problem, factors that will influence our decission are:
# -Addresstype
# -Sevetity of the collision
# -Collision types (Major/Minor)
# -Number of People affected
# -Weather conditions
#
# The above data attibute are the major items we are going to use in our data extraction and cleansinng processs for our ML program
#
# Expected objective is to get the location and the cause of the accident which occur with all these attributed so that government can take steps and start their funding based on the Data analysis report
#
# Data set is using the Data-Collisions.csv , Below is the link for the data set
#
# https://s3.us.cloud-object-storage.appdomain.cloud/cf-courses-data/CognitiveClass/DP0701EN/version-2/Data-Collisions.csv
#
# Total number of attributes: 38 Fields
# Total records : 252861
