# %% [markdown]
# # <font color='blue'>IntroductionBusiness Problem section</font>
#
# #### Problem Statement : To find the optimal solution to leverage the accidents occurances based on the different attibuted data with pre-defined ML model system in place
# #### The idea of this project is to help people planning their pre-requistes for the travel with regards of the location & Climatic conditions.

# %% [markdown]
# ## <font color='blue'>Description of the Data :</font>
#
# #### Accident occurance data with all the attibuted is defined with all the values requiredf for Data analysis / Data clensing ..etc
# #### Data set is using the Data-Collisions.csv , Below is the link for the data set
# #### https://s3.us.cloud-object-storage.appdomain.cloud/cf-courses-data/CognitiveClass/DP0701EN/version-2/Data-Collisions.csv
# #### Total number of attributes: 38 Fields
# #### Total records : 252861
